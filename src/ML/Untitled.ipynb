# %%
import tensorflow as tf

# Load the Keras model from .h5
model = tf.keras.models.load_model("model.h5")

# Save it as a TensorFlow SavedModel format
model.save("model.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import tensorflow as tf
#       3 # Load the Keras model from .h5
# ----> 4 model = tf.keras.models.load_model("model.h5")
#       6 # Save it as a TensorFlow SavedModel format
#       7 model.save("model.json")
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/lazy_loader.py:181, in KerasLazyLoader.__getattr__(self, item)
#     179   return super(types.ModuleType, self).__getattribute__(item)
#     180 if not self._tfll_initialized:
# --> 181   self._initialize()
#     182 if self._tfll_keras_version == "keras_3":
#     183   if (
#     184       self._tfll_mode == "v1"
#     185       and not self._tfll_submodule
#     186       and item.startswith("compat.v1.")
#     187   ):
#
# ...
